# %%
# !pip install pandas

# %%
# !pip install scikit-learn

# %%
# !pip install matplotlib

# %%
# !pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('Ecommerce Customers.csv')

# %%
data.isna().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
sns.jointplot(x='Time on Website', y='Yearly Amount Spent', data=data)

# %%
sns.jointplot(x='Time on App', y='Yearly Amount Spent', data=data)

# %%
sns.pairplot(data, kind='scatter')

# %%
sns.lmplot(x='Length of Membership', y='Yearly Amount Spent', data=data)

# %%
X_train, X_test, y_train, y_test = train_test_split(data[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']], data['Yearly Amount Spent'], test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
score = r2_score(y_test, predictions)
print(f"R-squared score: {score}")
# Out:
# R-squared score: 0.9808757641125855

# %%
sns.scatterplot(x= y_test, y= predictions)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs. Predicted Values')
# Out:
# Text(0.5, 1.0, 'Actual vs. Predicted Values')

# %%
model.score(X_train, y_train)
# Out:
# 0.9854085989105928

# %%
X_test
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 361            32.077590    10.347877        39.045156              3.434560
# 73             32.808698    12.817113        37.031539              3.851579
# 374            31.447446    10.101632        38.043453              4.238296
# 155            32.449522    13.457725        37.238806              2.941411
# 104            31.389585    10.994224        38.074452              3.428860
# ..                   ...          ...              ...                   ...
# 266            34.555283    11.777772        37.979827              3.784273
# 23             32.903251    11.657576        36.772604              3.919302
# 222            34.334865    11.109456        38.585855              3.892891
# 261            32.550527    13.041245        36.655208              3.456234
# 426            31.425227    13.271475        37.239847              4.022103
#
# [150 rows x 4 columns]

# %%
test1= model.predict([[32.077590, 10.347877, 39.045156, 3.434560]])
real1 = y_test[361]
print(test1)
print(real1)
# Out:
# [403.6699489]
# 401.0331352191061
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
score_test= model.score(X_test, y_test)
print(f"R-squared score: {score_test}")
# Out:
# R-squared score: 0.9808757641125855
